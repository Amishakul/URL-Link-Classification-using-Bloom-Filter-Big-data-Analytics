# %% [markdown]
# <a href="https://colab.research.google.com/github/Amishakul/.github-workflows/blob/main/URL_Links_Classification_using_bloom_filtering_BDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bitarray
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.5/286.5 kB 3.4 MB/s eta 0:00:00
# ...

# %%
# !pip install mmh3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.6/72.6 kB 2.0 MB/s eta 0:00:00
# ...

# %%
# Import required libraries
import mmh3
from bitarray import bitarray
import random

# Define the BloomFilter class
class BloomFilter:
    def __init__(self, size, hash_functions):
        self.size = size
        self.bit_array = bitarray(size)
        self.bit_array.setall(0)
        self.hash_functions = hash_functions

    def add(self, item):
        for i in range(self.hash_functions):
            index = mmh3.hash(item, i) % self.size
            self.bit_array[index] = 1

    def contains(self, item):
        for i in range(self.hash_functions):
            index = mmh3.hash(item, i) % self.size
            if self.bit_array[index] == 0:
                return False
        return True

# Define categories and their corresponding Bloom filters
categories = {
    "news": BloomFilter(size=1000, hash_functions=5),
    "sports": BloomFilter(size=1000, hash_functions=5),
    "tech": BloomFilter(size=1000, hash_functions=5),
    "social media": BloomFilter(size=1000, hash_functions=5),
    "graphics design": BloomFilter(size=1000, hash_functions=5),
    "shopping": BloomFilter(size=1000, hash_functions=5),
    "travel": BloomFilter(size=1000, hash_functions=5),
    "food": BloomFilter(size=1000, hash_functions=5),
    "coding": BloomFilter(size=1000, hash_functions=5),
    "fashion": BloomFilter(size=1000, hash_functions=5),
    "music": BloomFilter(size=1000, hash_functions=5),
    "search engines": BloomFilter(size=1000, hash_functions=5),
    "education": BloomFilter(size=1000, hash_functions=5),
    "health": BloomFilter(size=1000, hash_functions=5),
    "fitness": BloomFilter(size=1000, hash_functions=5),
    "entertainment": BloomFilter(size=1000, hash_functions=5),
    "science": BloomFilter(size=1000, hash_functions=5),
    "art": BloomFilter(size=1000, hash_functions=5),
    "travel": BloomFilter(size=1000, hash_functions=5),
    "ott": BloomFilter(size=1000, hash_functions=5),
    "beauty": BloomFilter(size=1000, hash_functions=5),
    "books": BloomFilter(size=1000, hash_functions=5),  # Added Books category
    # Add more categories here
}

# Define keywords for each category
keywords = {
    "news": ["news", "headline", "article", "cnn", "bbc", "nytimes", "reuters", "apnews", "guardian", "huffpost", "npr", "washingtonpost", "time", "usatoday", "latimes", "bloomberg", "cbsnews", "abcnews", "cnbc", "aljazeera", "politico", "vox", "newyorker", "nbcnews", "rferl", "dwnews", "independent", "newsweek", "forbes"],
    "sports": ["sports", "game", "score", "espn", "nba", "nfl", "nike", "adidas", "underarmour", "bleacherreport", "cbssports", "sbnation", "golfchannel", "foxsports", "mlb", "nascar", "skysports", "nfl", "nhl", "olympics", "athletics", "supersport", "worldathletics", "nbcsports", "eurosport", "realsport101", "sportskeeda"],
    "tech": ["tech", "technology", "gadget", "techcrunch", "engadget", "wired", "arstechnica", "slashdot", "mashable", "thenextweb", "gizmodo", "verge", "lifehacker", "wccftech", "androidcentral", "stackexchange", "xda-developers", "techspot", "cnet", "gsmarena", "phys", "techradar", "digitaltrends", "computerworld", "recode", "technologyreview"],
def generate_random_url(category):
    keywords_for_category = keywords[category]
    random_keyword = random.choice(keywords_for_category)
    random_url = f"https://www.{random_keyword}.com"
    return random_url

num_random_urls = 10  # Adjust this to the number of random URLs you want to classify
random_urls = {}
for category in categories:
    random_urls[category] = [generate_random_url(category) for _ in range(num_random_urls)]

# Classify each random URL
for category, urls in random_urls.items():
    for url_to_check in urls:
        categories[category].add(url_to_check)
        print(f"The URL '{url_to_check}' belongs to the '{category}' category.")

# Test classification for each random URL
for category, urls in random_urls.items():
    for url_to_check in urls:
        for category_name, filter in categories.items():
            if filter.contains(url_to_check):
                print(f"The URL '{url_to_check}' belongs to the '{category_name}' category.")
                break
        else:
            print(f"The URL '{url_to_check}' does not match any category.")
# Out:
# The URL 'https://www.reuters.com' belongs to the 'news' category.
# The URL 'https://www.headline.com' belongs to the 'news' category.
# The URL 'https://www.nytimes.com' belongs to the 'news' category.
# The URL 'https://www.usatoday.com' belongs to the 'news' category.
# The URL 'https://www.headline.com' belongs to the 'news' category.
# The URL 'https://www.guardian.com' belongs to the 'news' category.
# The URL 'https://www.bloomberg.com' belongs to the 'news' category.
# The URL 'https://www.huffpost.com' belongs to the 'news' category.
# The URL 'https://www.news.com' belongs to the 'news' category.
# The URL 'https://www.politico.com' belongs to the 'news' category.
# The URL 'https://www.sbnation.com' belongs to the 'sports' category.
# The URL 'https://www.supersport.com' belongs to the 'sports' category.
# The URL 'https://www.nfl.com' belongs to the 'sports' category.
# The URL 'https://www.realsport101.com' belongs to the 'sports' category.
# ...

# %%
import mmh3
from bitarray import bitarray

class BloomFilter:
    def __init__(self, size, hash_functions):
        self.size = size
        self.bit_array = bitarray(size)
        self.bit_array.setall(0)
        self.hash_functions = hash_functions

    def add(self, item):
        for i in range(self.hash_functions):
            index = mmh3.hash(item, i) % self.size
            self.bit_array[index] = 1

    def contains(self, item):
        for i in range(self.hash_functions):
            index = mmh3.hash(item, i) % self.size
            if self.bit_array[index] == 0:
                return False
        return True

# Create a Bloom filter for categorization
bloom_filter = BloomFilter(size=1000, hash_functions=5)

# Define existing categories and categorization rules (keywords)
categories = {
    "news": BloomFilter(size=1000, hash_functions=5),
    "sports": BloomFilter(size=1000, hash_functions=5),
    "tech": BloomFilter(size=1000, hash_functions=5),
    "social media": BloomFilter(size=1000, hash_functions=5),
    "graphics design": BloomFilter(size=1000, hash_functions=5),
    "shopping": BloomFilter(size=1000, hash_functions=5),
    "travel": BloomFilter(size=1000, hash_functions=5),
    "food": BloomFilter(size=1000, hash_functions=5),
    "coding": BloomFilter(size=1000, hash_functions=5),
    "fashion": BloomFilter(size=1000, hash_functions=5),
    "music": BloomFilter(size=1000, hash_functions=5),
    "search engines": BloomFilter(size=1000, hash_functions=5),
    "education": BloomFilter(size=1000, hash_functions=5),
    "health": BloomFilter(size=1000, hash_functions=5),
    "fitness": BloomFilter(size=1000, hash_functions=5),
    "entertainment": BloomFilter(size=1000, hash_functions=5),
    "science": BloomFilter(size=1000, hash_functions=5),
    "art": BloomFilter(size=1000, hash_functions=5),
    "ott": BloomFilter(size=1000, hash_functions=5),
    "beauty": BloomFilter(size=1000, hash_functions=5),
    "books": BloomFilter(size=1000, hash_functions=5),
    # Add more categories here
}

keywords = {
    "news": ["news", "headline", "article", "cnn", "bbc", "nytimes", "reuters", "apnews", "guardian", "huffpost", "npr", "washingtonpost", "time", "usatoday", "latimes", "bloomberg", "cbsnews", "abcnews", "cnbc", "aljazeera", "politico", "vox", "newyorker", "nbcnews", "rferl", "dwnews", "independent", "newsweek", "forbes"],
    "sports": ["sports", "game", "score", "espn", "nba", "nfl", "nike", "adidas", "underarmour", "bleacherreport", "cbssports", "sbnation", "golfchannel", "foxsports", "mlb", "nascar", "skysports", "nfl", "nhl", "olympics", "athletics", "supersport", "worldathletics", "nbcsports", "eurosport", "realsport101", "sportskeeda"],
    "tech": ["tech", "technology", "gadget", "techcrunch", "engadget", "wired", "arstechnica", "slashdot", "mashable", "thenextweb", "gizmodo", "verge", "lifehacker", "wccftech", "androidcentral", "stackexchange", "xda-developers", "techspot", "cnet", "gsmarena", "phys", "techradar", "digitaltrends", "computerworld", "recode", "technologyreview"],
    "social media": ["facebook", "twitter", "instagram", "linkedin", "pinterest", "tiktok", "reddit", "snapchat", "tumblr", "quora", "flickr", "vimeo", "meetup", "myspace", "vk", "weibo", "telegram", "whatsapp", "signal", "slack", "discord", "line", "kakao", "parler", "digg", "stumbleupon", "friendster"],
    "graphics design": ["canva", "adobe", "design", "graphics", "photoshop", "illustrator", "indesign", "coreldraw", "gimp", "inkscape", "blender", "pixlr", "vectr", "affinitydesigner", "sketchup", "figma", "gravitdesigner", "lunapic", "befunky", "befonts", "creativebloq", "typewolf", "cssdesignawards", "designboom", "designshack", "brandnew", "designmuseum"],
    "shopping": ["amazon", "flipkart", "ebay", "walmart", "target", "bestbuy", "alibaba", "etsy", "meesho", "myntra", "zalando", "overstock", "shopify", "newegg", "wayfair", "asos", "boohoo", "shein", "victoriassecret", "nordstrom", "macys", "costco", "kohls", "sephora", "homedepot", "lowes", "samsclub", "bloomingdales"],
    "coding": ["codepen", "github", "stackoverflow", "gitlab", "bitbucket", "hackerrank", "leetcode", "dev.to", "dzone", "freeCodeCamp", "codewars", "sitepoint", "css-tricks", "smashingmagazine", "itnext", "programiz", "codinghorror", "quora", "stackoverflow.blog", "sourcemaking", "programcreek", "geeksforgeeks", "w3schools", "javatpoint", "tutorialspoint", "pythontutorial", "codecademy"],
    "fashion": ["zara", "hm", "asos", "nordstrom", "forever21", "mango", "boohoo", "topshop", "gucci", "louisvuitton", "chanel", "hermes", "prada", "ralphlauren", "zegna", "tomford", "coach", "armani", "versace", "burberry", "dolcegabbana", "calvinklein", "givenchy", "tiffanyandco", "bally", "bulgari"],
    "travel": ["booking", "expedia", "tripadvisor", "kayak", "orbitz", "agoda", "airbnb", "trivago", "priceline", "hotels", "vrbo", "skyscanner", "lonelyplanet", "bookingbuddy", "travelzoo", "hoteltonight", "kiwi", "hostelworld", "travelsites", "travelpulse", "viator", "fodors", "cruisecritic", "cheapoair", "wegotour", "easytobook", "ebookers"],
    "music":  ["spotify", "ganna","hungama","youtube music","amazon music","wynk music","Apple music"],
    "food": ["food", "recipes", "cooking", "foodnetwork", "allrecipes", "epicurious", "tasty", "food52", "yummly", "cookpad", "chowhound", "seriouseats", "thespruceeats", "foodandwine", "delish", "tasteofhome", "bonappetit", "eatingwell", "foodgawker", "chefkoch", "bbcgoodfood", "food.com", "myrecipes", "saveur", "kitchn", "simpleveganblog", "veganricha"],
    "coding": ["codepen", "github", "stackoverflow", "gitlab", "bitbucket", "hackerrank", "leetcode", "dev.to", "dzone", "freeCodeCamp", "codewars", "sitepoint", "css-tricks", "smashingmagazine", "itnext", "programiz", "codinghorror", "quora", "stackoverflow.blog", "sourcemaking", "programcreek", "geeksforgeeks", "w3schools", "javatpoint", "tutorialspoint", "pythontutorial", "codecademy"],
    "search engines": ["google","firefox","google chorme","yahoo","duckduckgo","google email","google drive","google classroom"],
    "education": ["coursera", "udemy", "khanacademy", "edx", "codecademy", "pluralsight", "udacity", "futurelearn", "linkedinlearning", "skillshare", "treehouse", "openstax", "academicearth", "nptel", "mitopencourseware", "khanacademyindia", "byjus", "classcentral", "nasa", "britannica", "merriam-webster", "oxforddictionaries", "ted", "howstuffworks", "nationalgeographic", "britannica", "wikipedia", "encyclopedia"],
    "health": ["webmd", "mayoclinic", "healthline", "nih", "cdc", "who", "medlineplus", "mayo", "bmj", "nih", "medicalnewstoday", "healthaffairs", "euro.who", "jamanetwork", "thelancet", "nature", "nejm", "sciencedaily", "verywellhealth", "mindbodygreen", "healthcare", "psychologytoday", "psychiatry", "mayoclinic", "medscape", "psychology", "headspace", "betterhelp", "talkspace", "7cups", "mind.org", "mindtools", "healthgrades", "ratemds", "zocdoc", "vitals", "realself", "healthcentral", "doctors", "everydayhealth", "aarp", "webmd", "drugs", "rxlist"],
    "fitness": ["myfitnesspal", "bodybuilding", "muscleandfitness", "shape", "fitnessmagazine", "acefitness", "acefitness", "fitday", "muscleandstrength", "nhsfitness", "bodybuilding", "menshealth", "jillianmichaels", "popsugar", "self", "marieclaire", "womenshealthmag", "mensfitness", "prevention", "sparkpeople", "runnersworld", "active", "livestrong", "outsideonline", "greatist", "yogajournal", "fitnessblender", "blogilates", "acefitness", "popsugarfitness", "womenshealthmag", "shape", "everydayhealth"],
    "entertainment": ["imdb", "rottentomatoes", "metacritic", "tvguide", "ew", "hollywoodreporter", "variety", "deadline", "boxofficemojo", "aintitcool", "comingsoon", "darkhorizons", "screencrush", "cbr", "indiewire", "slashfilm", "collider", "joblo", "filmdrunk", "filmthreat", "letterboxd", "mrqe", "movies", "movieinsider", "moviefone", "boxofficemojo", "screenrant", "bleedingcool", "filmcomment", "hollywood", "rte", "filmfestivaltoday", "wildaboutmovies", "filmindependent"],
    "science": ["nasa", "nationalgeographic", "sciam", "scientificamerican", "nature", "smithsonianmag", "pbs", "popsci", "phys", "newscientist", "livescience", "space", "iflscience", "scientificamerican", "aaas", "theguardian", "biology", "physicsworld", "nature", "nasa", "noaa", "sciencesmag", "sciencefriday", "skyandtelescope", "space", "earthsky", "space", "sciencenews", "scientificamerican", "popsci", "livescience", "scifri", "skyandtelescope", "earthsky", "sciencesmag", "sciencefriday", "scimex", "theguardian", "phys.org", "sciencealert", "rte", "sciencefocus", "sciencenews"],
    "art": ["artstation", "deviantart", "behance", "dribbble", "artsy", "juxtapoz", "saatchiart", "artnet", "artforum", "artnews", "frieze", "whitewall", "hifructose", "moma", "tate", "guggenheim", "louvre", "britishmuseum", "metmuseum", "rijksmuseum", "nga", "getty", "sfmoma", "lacma", "whitneymuseum", "tate", "vam", "gagosian"],
    "ott": ["netflix", "amazonprime", "disneyplus", "hulu", "appletvplus", "hbomax", "peacocktv", "paramountplus", "fubo", "youtubetv", "slingtv", "vidangel", "tubitv", "crunchyroll", "funimation", "vrv", "shudder", "kanopy", "hoopla", "mubi", "bfiplayer", "filmin", "plex", "crave", "nowtv", "britbox", "acorn", "criterionchannel"],
    "beauty": ["nykaa", "sephora", "ulta", "cosmopolitan", "vogue", "allure", "elle", "glamour", "byrdie", "marieclaire", "beautyeditor", "beautyjunkies", "totalbeauty", "intothegloss", "birchbox", "ipsy", "soko-glam", "theordinary", "beautybay", "strawberrynet", "beautylish", "cultbeauty", "skinstore", "lookfantastic", "feelunique", "lovelyskin", "elfcosmetics", "clinique", "lancome", "bobbi-brown", "kyliecosmetics", "hudabeauty"],
    "books": ["goodreads", "bookbub", "bookdepository", "abebooks", "bookfinder", "kobo", "barnesandnoble", "bookriot", "booklist", "bookpage", "readingrockets", "theguardian", "nytimesbooks", "latimesbooks", "nprbooks", "theparisreview", "bookish", "kirkusreviews", "booktrust", "fantasticfiction", "gutenberg", "manybooks", "openlibrary", "e-reading", "bookperk", "earlybirdbooks", "bookstr", "bookbrowse", "freespiritpublishing", "bookgorilla", "bookangel", "readinggroupguides"],
    # Add more keywords for the new categories here
}

# Real-time URL generation and categorization
while True:
    url = input("Enter a URL (or 'exit' to stop): ")

    if url == 'exit':
        break

    category_assigned = False

    for category, filter in categories.items():
        for keyword in keywords[category]:
            if keyword in url:
                filter.add(url)
                print(f"The URL '{url}' belongs to the '{category}' category.")
                category_assigned = True
                break

    if not category_assigned:
        print(f"The URL '{url}' doesn't match any category.")
# Out:
# Enter a URL (or 'exit' to stop): www.amazon.in
# The URL 'www.amazon.in' belongs to the 'shopping' category.
# Enter a URL (or 'exit' to stop): exit
